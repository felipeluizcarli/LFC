# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeluizcarli/LFC/blob/main/seguda_Pratica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pratica

# %%
import gdown

# %%
# !gdown exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A

# %%
# !gdown 1exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1exmP2er4MvJ4yyaop3_yGhCYYmGb7s6A
# To: /content/SuperMercados.xlsx
# 100% 97.5k/97.5k [00:00<00:00, 78.2MB/s]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('SuperMercados.xlsx')

# %%
df. head()
# Out:
#    Unnamed: 0 ID da fatura Filial Tipo de Cliente Gênero  \
# 0         0.0  750-67-8428      A          Member      F
# 1         1.0  226-31-3081      C          Normal      F
# 2         2.0  631-41-3108      A          Normal      M
# 3         3.0  123-19-1176      A          Member      M
# 4         4.0  373-73-7910      A          Normal      M
#
#          Linha de produto  Preço unitário  Quantidade    Total       Data  \
# 0          Saúde e beleza         1120.35         7.0  7842.45   1/5/2019
# 1  Acessórios eletrônicos          229.20         5.0  1146.00   3/8/2019
# 2   Casa e estilo de vida          694.95         7.0  4864.65   3/3/2019
# 3          Saúde e beleza          873.30         8.0  6986.40  1/27/2019
# 4      Esportes e viagens         1294.65         7.0  9062.55   2/8/2019
#
#       Tempo          Pagamento       COGS  porcentagem de margem bruta  \
# 0  13:08:00                PIX  4705.4700                 4.761905e+09
# 1  10:29:00           Dinheiro  1031.4000                 4.761905e+09
# 2  13:23:00  Cartão de Crédito  3405.2550                 4.761905e+09
# 3  20:33:00                PIX  4191.8400                 4.761905e+09
# 4  10:37:00                PIX  6796.9125                 4.761905e+09
#
#    renda bruta  Avaliação
# 0     261415.0       91.0
# 1        382.0       96.0
# 2     162155.0       74.0
# 3      23288.0       84.0
# 4     302085.0       53.0

# %%
sns.heatmap(df.isnull(),
            yticklabels = False,
            cbar = False,
            cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df
# Out:
#     ID da fatura Filial Tipo de Cliente Gênero        Linha de produto  \
# 0    750-67-8428      A          Member      F          Saúde e beleza
# 1    226-31-3081      C          Normal      F  Acessórios eletrônicos
# 2    631-41-3108      A          Normal      M   Casa e estilo de vida
# 3    123-19-1176      A          Member      M          Saúde e beleza
# 4    373-73-7910      A          Normal      M      Esportes e viagens
# ..           ...    ...             ...    ...                     ...
# 995  233-67-5758      C          Normal      M          Saúde e beleza
# 996  303-96-2227      B          Normal      F   Casa e estilo de vida
# 997  727-02-1313      A          Member      M        Comida e bebidas
# 998  347-56-2442      A          Normal      M   Casa e estilo de vida
# 999  849-09-3807      A          Member      F     Acessórios fashions
#
#      Preço unitário  Quantidade     Total       Data     Tempo  \
# 0           1120.35         7.0   7842.45   1/5/2019  13:08:00
# 1            229.20         5.0   1146.00   3/8/2019  10:29:00
# 2            694.95         7.0   4864.65   3/3/2019  13:23:00
# 3            873.30         8.0   6986.40  1/27/2019  20:33:00
# 4           1294.65         7.0   9062.55   2/8/2019  10:37:00
# ..              ...         ...       ...        ...       ...
# 995          605.25         1.0    605.25  1/29/2019  13:46:00
# 996         1460.70        10.0  14607.00   3/2/2019  17:16:00
# 997          477.60         1.0    477.60   2/9/2019  13:22:00
# 998          987.30         1.0    987.30  2/22/2019  15:33:00
# 999         1325.10         7.0   9275.70  2/18/2019  13:28:00
#
#              Pagamento        COGS  porcentagem de margem bruta  renda bruta  \
# 0                  PIX   4705.4700                 4.761905e+09     261415.0
# 1             Dinheiro   1031.4000                 4.761905e+09        382.0
# 2    Cartão de Crédito   3405.2550                 4.761905e+09     162155.0
# 3                  PIX   4191.8400                 4.761905e+09      23288.0
# 4                  PIX   6796.9125                 4.761905e+09     302085.0
# ..                 ...         ...                          ...          ...
# 995                PIX    363.1500                 4.761905e+09      20175.0
# 996                PIX  10224.9000                 4.761905e+09       4869.0
# 997           Dinheiro    405.9600                 4.761905e+09       1592.0
# 998           Dinheiro    691.1100                 4.761905e+09       3291.0
# 999           Dinheiro   6956.7750                 4.761905e+09      30919.0
#
#      Avaliação
# 0         91.0
# 1         96.0
# 2         74.0
# 3         84.0
# 4         53.0
# ..         ...
# 995       62.0
# 996       44.0
# 997       77.0
# 998       41.0
# 999       66.0
#
# [1000 rows x 15 columns]

# %%
df.drop(columns = ['porcentagem de margem bruta' ,'renda bruta','ID da fatura'], inplace = True)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A          Member      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A          Member      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A          Member      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A          Member      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0           7.0   7842.45   1/5/2019  13:08:00                PIX   4705.4700
# 1           5.0   1146.00   3/8/2019  10:29:00           Dinheiro   1031.4000
# 2           7.0   4864.65   3/3/2019  13:23:00  Cartão de Crédito   3405.2550
# 3           8.0   6986.40  1/27/2019  20:33:00                PIX   4191.8400
# 4           7.0   9062.55   2/8/2019  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995         1.0    605.25  1/29/2019  13:46:00                PIX    363.1500
# 996        10.0  14607.00   3/2/2019  17:16:00                PIX  10224.9000
# 997         1.0    477.60   2/9/2019  13:22:00           Dinheiro    405.9600
# 998         1.0    987.30  2/22/2019  15:33:00           Dinheiro    691.1100
# 999         7.0   9275.70  2/18/2019  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0         91.0
# 1         96.0
# 2         74.0
# 3         84.0
# 4         53.0
# ..         ...
# 995       62.0
# 996       44.0
# 997       77.0
# 998       41.0
# 999       66.0
#
# [1000 rows x 12 columns]

# %%
df.replace({'Tipo de Cliente' : {'Member' : 'Associado'}}, inplace = True)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0           7.0   7842.45   1/5/2019  13:08:00                PIX   4705.4700
# 1           5.0   1146.00   3/8/2019  10:29:00           Dinheiro   1031.4000
# 2           7.0   4864.65   3/3/2019  13:23:00  Cartão de Crédito   3405.2550
# 3           8.0   6986.40  1/27/2019  20:33:00                PIX   4191.8400
# 4           7.0   9062.55   2/8/2019  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995         1.0    605.25  1/29/2019  13:46:00                PIX    363.1500
# 996        10.0  14607.00   3/2/2019  17:16:00                PIX  10224.9000
# 997         1.0    477.60   2/9/2019  13:22:00           Dinheiro    405.9600
# 998         1.0    987.30  2/22/2019  15:33:00           Dinheiro    691.1100
# 999         7.0   9275.70  2/18/2019  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0         91.0
# 1         96.0
# 2         74.0
# 3         84.0
# 4         53.0
# ..         ...
# 995       62.0
# 996       44.0
# 997       77.0
# 998       41.0
# 999       66.0
#
# [1000 rows x 12 columns]

# %%
df ['Data'].unique()
# Out:
# array(['1/5/2019', '3/8/2019', '3/3/2019', '1/27/2019', '2/8/2019',
#        '3/25/2019', '2/25/2019', '2/24/2019', '1/10/2019', '2/20/2019',
#        '2/6/2019', '3/9/2019', '2/12/2019', '2/7/2019', '3/29/2019',
#        '1/15/2019', '3/11/2019', '1/1/2019', '1/21/2019', '3/5/2019',
#        '3/15/2019', '2/17/2019', '3/2/2019', '3/22/2019', '3/10/2019',
#        '1/25/2019', '1/28/2019', '1/7/2019', '3/23/2019', '1/17/2019',
#        '2/2/2019', '3/4/2019', '3/16/2019', '2/27/2019', '2/10/2019',
#        '3/19/2019', '2/3/2019', '3/7/2019', '2/28/2019', '3/27/2019',
#        '1/20/2019', '3/12/2019', '2/15/2019', '3/6/2019', '2/14/2019',
#        '3/13/2019', '1/24/2019', '1/6/2019', '2/11/2019', '1/22/2019',
#        '1/13/2019', '1/9/2019', '1/12/2019', '1/26/2019', '1/23/2019',
#        '2/23/2019', '1/2/2019', '2/9/2019', '3/26/2019', '3/1/2019',
#        '2/1/2019', '3/28/2019', '3/24/2019', '2/5/2019', '1/19/2019',
#        '1/16/2019', '1/8/2019', '2/18/2019', '1/18/2019', '2/16/2019',
#        '2/22/2019', '1/29/2019', '1/4/2019', '3/30/2019', '1/30/2019',
#        '1/3/2019', '3/21/2019', '2/13/2019', '1/14/2019', '3/18/2019',
#        '3/20/2019', '2/21/2019', '1/31/2019', '1/11/2019', '2/26/2019',
#        '3/17/2019', '3/14/2019', '2/4/2019', '2/19/2019'], dtype=object)

# %%
df['Data'] = pd.to_datetime(df['Data'])

# %%
df['Data']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Data, Length: 1000, dtype: datetime64[ns]

# %%
df['Horário'] = pd.to_datetime(df['Horário'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Horário'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-59c4118edbeb> in <module>
# ----> 1 df['Horário'] = pd.to_datetime(df['Horário'])
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Horário'

# %%
df['Horário']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Horário'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-39a52bbe2593> in <module>
# ----> 1 df['Horário']
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Horário'

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Filial                      object
# Tipo de Cliente             object
# Gênero                      object
# Linha de produto            object
# Preço unitário             float64
# Quantidade                 float64
# Total                      float64
# Data                datetime64[ns]
# Tempo                       object
# Pagamento                   object
# COGS                       float64
# Avaliação                  float64
# dtype: object

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0           7.0   7842.45 2019-01-05  13:08:00                PIX   4705.4700
# 1           5.0   1146.00 2019-03-08  10:29:00           Dinheiro   1031.4000
# 2           7.0   4864.65 2019-03-03  13:23:00  Cartão de Crédito   3405.2550
# 3           8.0   6986.40 2019-01-27  20:33:00                PIX   4191.8400
# 4           7.0   9062.55 2019-02-08  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995         1.0    605.25 2019-01-29  13:46:00                PIX    363.1500
# 996        10.0  14607.00 2019-03-02  17:16:00                PIX  10224.9000
# 997         1.0    477.60 2019-02-09  13:22:00           Dinheiro    405.9600
# 998         1.0    987.30 2019-02-22  15:33:00           Dinheiro    691.1100
# 999         7.0   9275.70 2019-02-18  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0         91.0
# 1         96.0
# 2         74.0
# 3         84.0
# 4         53.0
# ..         ...
# 995       62.0
# 996       44.0
# 997       77.0
# 998       41.0
# 999       66.0
#
# [1000 rows x 12 columns]

# %%
meses = {1: 'Janeiro', 2: 'Fevereiro', 3: 'Março'}

# %%
pd.to_datetime(df['Data']).dt.month.map(meses)
# Out:
# 0        Janeiro
# 1          Março
# 2          Março
# 3        Janeiro
# 4      Fevereiro
#          ...
# 995      Janeiro
# 996        Março
# 997    Fevereiro
# 998    Fevereiro
# 999    Fevereiro
# Name: Data, Length: 1000, dtype: object

# %%
df['Data'] = pd.to_datetime(df['Data']).dt.month.map(meses)

# %%
df
# Out:
#     Filial Tipo de Cliente Gênero        Linha de produto  Preço unitário  \
# 0        A       Associado      F          Saúde e beleza         1120.35
# 1        C          Normal      F  Acessórios eletrônicos          229.20
# 2        A          Normal      M   Casa e estilo de vida          694.95
# 3        A       Associado      M          Saúde e beleza          873.30
# 4        A          Normal      M      Esportes e viagens         1294.65
# ..     ...             ...    ...                     ...             ...
# 995      C          Normal      M          Saúde e beleza          605.25
# 996      B          Normal      F   Casa e estilo de vida         1460.70
# 997      A       Associado      M        Comida e bebidas          477.60
# 998      A          Normal      M   Casa e estilo de vida          987.30
# 999      A       Associado      F     Acessórios fashions         1325.10
#
#      Quantidade     Total       Data     Tempo          Pagamento        COGS  \
# 0           7.0   7842.45    Janeiro  13:08:00                PIX   4705.4700
# 1           5.0   1146.00      Março  10:29:00           Dinheiro   1031.4000
# 2           7.0   4864.65      Março  13:23:00  Cartão de Crédito   3405.2550
# 3           8.0   6986.40    Janeiro  20:33:00                PIX   4191.8400
# 4           7.0   9062.55  Fevereiro  10:37:00                PIX   6796.9125
# ..          ...       ...        ...       ...                ...         ...
# 995         1.0    605.25    Janeiro  13:46:00                PIX    363.1500
# 996        10.0  14607.00      Março  17:16:00                PIX  10224.9000
# 997         1.0    477.60  Fevereiro  13:22:00           Dinheiro    405.9600
# 998         1.0    987.30  Fevereiro  15:33:00           Dinheiro    691.1100
# 999         7.0   9275.70  Fevereiro  13:28:00           Dinheiro   6956.7750
#
#      Avaliação
# 0         91.0
# 1         96.0
# 2         74.0
# 3         84.0
# 4         53.0
# ..         ...
# 995       62.0
# 996       44.0
# 997       77.0
# 998       41.0
# 999       66.0
#
# [1000 rows x 12 columns]

# %%
time = []
for i in list (map(int, df [Horário])):
  if i > 8 and i < 13:
    time.append ('Manhã')
  elif i > 12 and i < 19:
    time.append('Tarde')
  else:
    time.append('Noite')
df['Horário'] = time
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-e1d875eba5e7> in <module>
#       1 time = []
# ----> 2 for i in list (map(int, df [Horário])):
#       3   if i > 8 and i < 13:
#       4     time.append ('Manhã')
#       5   elif i > 12 and i < 19:
#
# NameError: name 'Horário' is not defined
